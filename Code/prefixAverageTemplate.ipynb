# %% [markdown]
# <a href="https://colab.research.google.com/github/hrbae/Data_Structures/blob/main/Code/prefixAverageTemplate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PrefixAverage(누적평균)
# - 주어진 배열에 i번째까지 합을 구하여 이것을 배열로 저장
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Code Here...........................................................................

# %% [markdown]
# 차례대로 넣는게 아니라 랜덤한 숫자로 넣어서 배열 확인해보기

# %% [markdown]
# # PrefixAverage Linear

# %% [markdown]
# 위 알고리즘을 n을 n번 돌게 되기때문에 Big-O(계산복잡도)가 n의 제곱이 된다.
# 이걸 해결하기위해 linear하게도 만들 수 있다.
# - 합을 미리 저장해두는 방식으로 더 빠르게 구할 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
